# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import SGDRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("Superconductor_temp.csv")

X, Y = df.iloc[:, :-1], df.iloc[:, -1]

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, train_size = 0.7)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.fit_transform(X_test)

Y_train, Y_test = Y_train.to_numpy(), Y_test.to_numpy()

# %%
sgdr = SGDRegressor()
sgdr.fit(X_train, Y_train)
print(sgdr)
print(f"number of iterations completed: {sgdr.n_iter_}, number of weight updates: {sgdr.t_}")

print((sgdr.coef_, sgdr.intercept_))
# Out:
# SGDRegressor()
# number of iterations completed: 91, number of weight updates: 1354445.0
# (array([ -6.34067576,  10.01318629,  -5.9312164 ,  -1.56505021,
#         -1.25732992, -13.91175815,   5.11391324,  10.57177966,
#          0.49657089,  -5.24190177,  -4.52052362,   3.02987144,
#          3.55499368,  -1.8748098 ,  -1.50303333,   2.1543013 ,
#          7.55919934,  19.34805062,   3.44002908, -15.61052323,
#         -4.75741962,  10.96386111,  19.71277913, -17.21298794,
#        -13.05421607,   0.15134978,  10.50920096,  16.74733328,
#         -3.69013403, -21.86755942,  10.05012223, -10.58089538,
#         -1.99933357,   2.3030537 ,   8.87142916,   5.56562376,
#         -6.72297858,  -4.44557326,   0.02601878,   7.81907103,
#         -2.69112267,  -1.5381298 ,  15.82984274,   3.58956561,
#        -16.44562308,   0.52513799,  -5.96190975, -21.31219748,
#         -4.86069281,  25.63793409,  -9.91362211,   4.56748754,
# ...

# %%
#from sklearn.preprocessing import PolynomialFeatures

# %%
# poly = PolynomialFeatures(degree=2, include_bias=False)
# X_ = poly.fit_transform(X_train)
# predict_ = poly.fit_transform(X_test)

# %%
# from sklearn import linear_model

# clf = linear_model.LinearRegression()
# clf.fit(X_, Y_train)
# print(clf)

# %%
Y_predicted = sgdr.predict(X_test)

# %%
# Y_predicted = clf.predict(predict_)

# %%
import random

n = 5


for i in range(n):
    index = random.randint(0, 80)
    fig = plt.figure()
    ax = fig.add_axes([0,0,1,1])
    ax.scatter(X_test[:, index], Y_test, color='r')
    ax.scatter(X_test[:, index], Y_predicted, color='b')
    plt.show()

# %%
#cost

def cost(Y_pred, Y_test):
    totalCost = 0
    sz = len(Y_test)
    
    for i in range(sz):
        totalCost += (Y_pred[i] - Y_test[i])**2
    
    return totalCost/(2*sz)

# %%
print(cost(Y_predicted, Y_test))
# Out:
# 155.8852687627203
